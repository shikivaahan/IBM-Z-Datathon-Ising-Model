# %%
import networkx as nx
import pandas as pd
import sys
import os

src_path = os.path.abspath(os.path.join('..', 'src'))
sys.path.append(src_path)

from data_processing.scrape import scrape
from network_graph.graph_handling import create_graph, export_graph_to_csv
from network_graph.visualisation import visualise_graph

# %%
df = scrape('soccer', 3)
# Out:
# Fetching comments for post: Support Your Local Saturday - for match-going and local fans
# URL: https://www.reddit.com/r/soccer/comments/1g74314/support_your_local_saturday_for_matchgoing_and/
#
# Fetching comments for post: Daily Discussion
# URL: https://www.reddit.com/r/soccer/comments/1g78e8x/daily_discussion/
#
# Fetching comments for post: Sneijder : “Busquets was an extremely annoying player, always giving it to others but never able to receive it. As soon as he received one hit he would start crying. I had fights with him every single game. At one point I told him: I will see you in Ibiza in the summer, then we'll talk again.”
# URL: https://sports.yahoo.com/former-real-madrid-star-hits-190000211.html

# %%
G = create_graph('user', 'replying_to', df)
visualise_graph(G)

# %%
folder_path = R'C:\Users\User\OneDrive - Imperial College London\Desktop\Documents\GitHub\IBM-Datathon\Dataset\raw_graph'

nodes_df = pd.DataFrame.from_dict(dict(G.nodes(data=True)), orient='index')
edges_df = nx.to_pandas_edgelist(G)

node_csv_path = os.path.join(folder_path, 'nodes_list.csv')
edge_csv_path = os.path.join(folder_path, 'edges_list.csv')

nodes_df.to_csv(node_csv_path, index=False)
edges_df.to_csv(edge_csv_path, index=False)

folder_path = r'C:\Users\User\OneDrive - Imperial College London\Desktop\Documents\GitHub\IBM-Datathon\Dataset\raw_data'
csv_file_path = os.path.join(folder_path, 'reddit_data_raw.csv')

df.to_csv(csv_file_path, index=False)
